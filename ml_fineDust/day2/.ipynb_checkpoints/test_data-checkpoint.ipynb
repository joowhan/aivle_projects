# %%
from sklearn.pipeline import Pipeline, make_pipeline

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
#read Kor - Window
from matplotlib import font_manager, rc
# font_path = "C:/Windows/Fonts/NGULIM.TTF"
# font = font_manager.FontProperties(fname=font_path).get_name()
# rc('font', family=font)
#- Mac
# %matplotlib inline
rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, Lasso, Ridge, ElasticNet
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score as acc
from sklearn.metrics import recall_score as recall
import joblib

import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format = 'retina'

# %%
test_data = pd.read_csv('test.csv')

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2441 entries, 0 to 2440
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2441 non-null   int64
#  1   url_len                  2441 non-null   int64
#  2   url_num_hyphens_dom      2441 non-null   int64
#  3   url_path_len             1975 non-null   float64
#  4   url_domain_len           1975 non-null   float64
#  5   url_hostname_len         1978 non-null   float64
#  6   url_num_dots             2441 non-null   int64
#  7   url_num_underscores      2441 non-null   int64
#  8   url_query_len            2441 non-null   int64
#  9   url_num_query_para       2441 non-null   int64
#  10  url_ip_present           2441 non-null   int64
#  11  url_entropy              2441 non-null   float64
#  12  url_chinese_present      2441 non-null   int64
#  13  url_port                 2441 non-null   int64
#  14  html_num_tags('iframe')  2441 non-null   int64
#  15  html_num_tags('script')  1974 non-null   float64
#  16  html_num_tags('embed')   2441 non-null   int64
#  17  html_num_tags('object')  2441 non-null   int64
#  18  html_num_tags('div')     2441 non-null   int64
#  19  html_num_tags('head')    2441 non-null   int64
#  20  html_num_tags('body')    2441 non-null   int64
#  21  html_num_tags('form')    1974 non-null   float64
#  22  html_num_tags('a')       1980 non-null   float64
#  23  html_num_tags('applet')  2441 non-null   int64
# dtypes: float64(7), int64(17)
# memory usage: 457.8 KB

# %%
test_data.isna().sum()
# Out:
# id                           0
# url_len                      0
# url_num_hyphens_dom          0
# url_path_len                 0
# url_domain_len               0
# url_hostname_len             0
# url_num_dots                 0
# url_num_underscores          0
# url_query_len                0
# url_num_query_para           0
# url_ip_present               0
# url_entropy                  0
# url_chinese_present          0
# url_port                     0
# html_num_tags('iframe')      0
# html_num_tags('script')      0
# html_num_tags('embed')       0
# html_num_tags('object')      0
# html_num_tags('div')         0
# html_num_tags('head')        0
# html_num_tags('body')        0
# html_num_tags('form')      467
# html_num_tags('a')         461
# html_num_tags('applet')      0
# dtype: int64

# %%
plt.hist(test_data['url_path_len'])
# Out:
# (array([1.941e+03, 2.400e+01, 4.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 2.000e+00, 0.000e+00, 2.000e+00]),
#  array([   0. ,  163.1,  326.2,  489.3,  652.4,  815.5,  978.6, 1141.7,
#         1304.8, 1467.9, 1631. ]),
#  <BarContainer object of 10 artists>)

# %%
test_data['url_path_len'].max()
# Out:
# 1631.0

# %%
test_data['url_path_len'].mean()
# Out:
# 27.541772151898734

# %%
test_data['url_path_len'].min()
# Out:
# 0.0

# %%
test_data['url_path_len'].median()
# Out:
# 12.0

# %%
# url_path_len: Na -> median
test_data.loc[test_data['url_path_len'].isnull(),'url_path_len'] = test_data['url_path_len'].median()

# %%
#url_domain_len
plt.hist(test_data['url_domain_len'])
# Out:
# (array([ 354., 1115.,  309.,  155.,   27.,    7.,    4.,    2.,    0.,
#            2.]),
#  array([  4. ,  13.6,  23.2,  32.8,  42.4,  52. ,  61.6,  71.2,  80.8,
#          90.4, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(test_data['url_domain_len'])

# %%
sns.kdeplot(x='url_domain_len', data=test_data)
# Out:
# <AxesSubplot:xlabel='url_domain_len', ylabel='Density'>

# %%
test_data['url_domain_len'].max()
# Out:
# 100.0

# %%
test_data['url_domain_len'].min()
# Out:
# 4.0

# %%
test_data['url_domain_len'].mean()
# Out:
# 20.262784810126583

# %%
test_data['url_domain_len'].median()
# Out:
# 17.0

# %%
# 가설1
test_data.nunique()
# Out:
# id                         2441
# url_len                     203
# url_num_hyphens_dom           7
# url_path_len                157
# url_domain_len               56
# url_hostname_len             57
# url_num_dots                 16
# url_num_underscores          16
# url_query_len                57
# url_num_query_para            9
# url_ip_present                2
# url_entropy                1791
# url_chinese_present           1
# url_port                      2
# html_num_tags('iframe')       9
# html_num_tags('script')      64
# html_num_tags('embed')        4
# html_num_tags('object')       6
# html_num_tags('div')        256
# html_num_tags('head')         4
# html_num_tags('body')         4
# html_num_tags('form')        10
# html_num_tags('a')          240
# html_num_tags('applet')       1
# dtype: int64

# %%
plt.scatter(test_data['url_path_len'], test_data['url_domain_len'])

# %%
sns.scatterplot(y='url_hostname_len',x='url_domain_len', data=test_data)
# Out:
# <AxesSubplot:xlabel='url_domain_len', ylabel='url_hostname_len'>

# %%
#path len과 hostname, domain len은 연관성이없다. 
sns.scatterplot(y='url_path_len',x='url_hostname_len', data=test_data)
# Out:
# <AxesSubplot:xlabel='url_hostname_len', ylabel='url_path_len'>

# %%
plt.hist(test_data['url_hostname_len'])
# Out:
# (array([3.730e+02, 1.025e+03, 3.800e+02, 1.490e+02, 3.700e+01, 6.000e+00,
#         4.000e+00, 3.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 4. , 13.5, 23. , 32.5, 42. , 51.5, 61. , 70.5, 80. , 89.5, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
test_data.loc[test_data['url_domain_len'].isnull() &test_data['url_hostname_len'].isnull() ].shape[0]
# Out:
# 101

# %%
test_data.loc[test_data['url_domain_len'].isnull() &test_data['url_hostname_len'].notnull()].shape[0]
# Out:
# 0

# %%
test_data.loc[test_data['url_domain_len'].notnull() &test_data['url_hostname_len'].isnull()].shape[0]
# Out:
# 0

# %%
test_data.loc[test_data['url_domain_len']!= test_data['url_hostname_len']].shape[0]
# Out:
# 122

# %%
test_data['url_hostname_len'] = test_data['url_hostname_len'].fillna(test_data['url_domain_len'])

# %%
test_data['url_domain_len'] = test_data['url_domain_len'].fillna(test_data['url_hostname_len'])

# %%
test_data['url_hostname_len'].max()
# Out:
# 100.0

# %%
test_data['url_hostname_len'].min()
# Out:
# 4.0

# %%
test_data['url_hostname_len'].median()
# Out:
# 17.0

# %%
test_data['url_hostname_len'].mean()
# Out:
# 20.257264957264958

# %%
plt.hist(test_data['url_domain_len'])
# Out:
# (array([ 425., 1309.,  366.,  190.,   33.,    9.,    4.,    2.,    0.,
#            2.]),
#  array([  4. ,  13.6,  23.2,  32.8,  42.4,  52. ,  61.6,  71.2,  80.8,
#          90.4, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
# url_domain_len: Na -> median
test_data.loc[test_data['url_domain_len'].isnull(),'url_domain_len'] = test_data['url_domain_len'].median()

# %%
test_data.loc[test_data['url_hostname_len'].isnull(),'url_hostname_len'] = test_data['url_hostname_len'].median()

# %%
plt.plot(test_data["html_num_tags('script')"])

# %%
plt.hist(test_data["html_num_tags('script')"])
# Out:
# (array([1.589e+03, 2.950e+02, 6.500e+01, 1.200e+01, 8.000e+00, 3.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([  0. ,  15.8,  31.6,  47.4,  63.2,  79. ,  94.8, 110.6, 126.4,
#         142.2, 158. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x="html_num_tags('a')",y="html_num_tags('div')", data=test_data)
# Out:
# <AxesSubplot:xlabel="html_num_tags('a')", ylabel="html_num_tags('div')">

# %%
test_data["html_num_tags('script')"].max()
# Out:
# 158.0

# %%
test_data["html_num_tags('script')"].min()
# Out:
# 0.0

# %%
test_data["html_num_tags('script')"].mean()
# Out:
# 8.763931104356637

# %%
test_data["html_num_tags('script')"].median()
# Out:
# 4.0

# %%
sns.scatterplot(x="html_num_tags('a')",y="html_num_tags('div')", data=test_data)
# Out:
# <AxesSubplot:xlabel="html_num_tags('a')", ylabel="html_num_tags('div')">

# %%
# "html_num_tags('script')"
test_data.loc[test_data["html_num_tags('script')"].isnull(),"html_num_tags('script')"] = test_data["html_num_tags('script')"].median()

# %%
test_data.corr()
# Out:
#                                id   url_len  url_num_hyphens_dom  \
# id                       1.000000 -0.018106            -0.008752
# url_len                 -0.018106  1.000000            -0.019285
# url_num_hyphens_dom     -0.008752 -0.019285             1.000000
# url_path_len            -0.029186  0.848095            -0.094565
# url_domain_len           0.011118  0.041278             0.602689
# url_hostname_len         0.011500  0.042405             0.603233
# url_num_dots            -0.032843  0.233569            -0.086556
# url_num_underscores      0.014212  0.360245            -0.066190
# url_query_len            0.002151  0.436731             0.024104
# url_num_query_para       0.000766  0.401446             0.020637
# url_ip_present           0.002985 -0.045055            -0.134414
# url_entropy              0.025233  0.295838             0.079870
# url_chinese_present           NaN       NaN                  NaN
# url_port                -0.015112 -0.005816            -0.010450
# html_num_tags('iframe')  0.005143  0.059416            -0.065746
# html_num_tags('script')  0.015399 -0.034973            -0.113903
# html_num_tags('embed')  -0.028417 -0.018379            -0.058324
# html_num_tags('object') -0.016843 -0.034092            -0.062946
# html_num_tags('div')     0.038500 -0.036667            -0.000400
# html_num_tags('head')   -0.020611  0.027708             0.029801
# html_num_tags('body')   -0.037040  0.047080             0.002167
# html_num_tags('form')    0.017098  0.014908             0.057764
# html_num_tags('a')       0.010064 -0.022839            -0.038158
# html_num_tags('applet')       NaN       NaN                  NaN
#
#                          url_path_len  url_domain_len  url_hostname_len  \
# id                          -0.029186        0.011118          0.011500
# url_len                      0.848095        0.041278          0.042405
# url_num_hyphens_dom         -0.094565        0.602689          0.603233
# url_path_len                 1.000000       -0.083281         -0.082324
# url_domain_len              -0.083281        1.000000          0.999438
# url_hostname_len            -0.082324        0.999438          1.000000
# url_num_dots                 0.103991        0.034673          0.032782
# url_num_underscores          0.153780       -0.070091         -0.069261
# url_query_len                0.013133        0.056351          0.056697
# url_num_query_para           0.015311        0.047840          0.048269
# url_ip_present              -0.028717       -0.169238         -0.180830
# url_entropy                  0.131467        0.159978          0.163617
# url_chinese_present               NaN             NaN               NaN
# url_port                    -0.003638       -0.007424         -0.019115
# html_num_tags('iframe')      0.080491       -0.041889         -0.041218
# html_num_tags('script')     -0.018587       -0.071385         -0.069513
# html_num_tags('embed')      -0.010334       -0.012159         -0.011788
# html_num_tags('object')     -0.022368       -0.034602         -0.036494
# html_num_tags('div')        -0.024239       -0.001186         -0.000005
# html_num_tags('head')        0.035421       -0.007659         -0.007583
# html_num_tags('body')       -0.002048        0.052404          0.052541
# html_num_tags('form')       -0.001924        0.020192          0.022462
# html_num_tags('a')          -0.010630       -0.031333         -0.030827
# html_num_tags('applet')           NaN             NaN               NaN
#
#                          url_num_dots  url_num_underscores  url_query_len  \
# id                          -0.032843             0.014212       0.002151
# url_len                      0.233569             0.360245       0.436731
# url_num_hyphens_dom         -0.086556            -0.066190       0.024104
# url_path_len                 0.103991             0.153780       0.013133
# url_domain_len               0.034673            -0.070091       0.056351
# url_hostname_len             0.032782            -0.069261       0.056697
# url_num_dots                 1.000000             0.365968       0.286159
# url_num_underscores          0.365968             1.000000       0.499477
# url_query_len                0.286159             0.499477       1.000000
# url_num_query_para           0.339343             0.500507       0.911999
# url_ip_present               0.266142             0.010535       0.004242
# url_entropy                  0.195053             0.294043       0.317549
# url_chinese_present               NaN                  NaN            NaN
# url_port                     0.020869            -0.004627      -0.002908
# html_num_tags('iframe')      0.004760            -0.011829      -0.014149
# html_num_tags('script')     -0.085725            -0.043561      -0.034905
# html_num_tags('embed')      -0.029524            -0.002268      -0.016231
# html_num_tags('object')     -0.019709            -0.015334      -0.017518
# html_num_tags('div')        -0.089583            -0.058513      -0.025677
# html_num_tags('head')       -0.024565             0.019009       0.003574
# html_num_tags('body')       -0.034114             0.008656       0.092019
# html_num_tags('form')       -0.088786            -0.067010       0.028988
# html_num_tags('a')          -0.042389            -0.014733      -0.016751
# html_num_tags('applet')           NaN                  NaN            NaN
#
#                          url_num_query_para  ...  html_num_tags('iframe')  \
# id                                 0.000766  ...                 0.005143
# url_len                            0.401446  ...                 0.059416
# url_num_hyphens_dom                0.020637  ...                -0.065746
# url_path_len                       0.015311  ...                 0.080491
# url_domain_len                     0.047840  ...                -0.041889
# url_hostname_len                   0.048269  ...                -0.041218
# url_num_dots                       0.339343  ...                 0.004760
# url_num_underscores                0.500507  ...                -0.011829
# url_query_len                      0.911999  ...                -0.014149
# url_num_query_para                 1.000000  ...                -0.016889
# url_ip_present                     0.011221  ...                -0.025129
# url_entropy                        0.325526  ...                -0.007718
# url_chinese_present                     NaN  ...                      NaN
# url_port                          -0.003357  ...                -0.004999
# html_num_tags('iframe')           -0.016889  ...                 1.000000
# html_num_tags('script')           -0.049467  ...                 0.286591
# html_num_tags('embed')            -0.018736  ...                 0.034674
# html_num_tags('object')           -0.020220  ...                 0.010788
# html_num_tags('div')              -0.026887  ...                 0.135321
# html_num_tags('head')              0.000285  ...                 0.004442
# html_num_tags('body')              0.088190  ...                -0.037133
# html_num_tags('form')              0.028738  ...                 0.157678
# html_num_tags('a')                -0.020022  ...                 0.042827
# html_num_tags('applet')                 NaN  ...                      NaN
#
#                          html_num_tags('script')  html_num_tags('embed')  \
# id                                      0.015399               -0.028417
# url_len                                -0.034973               -0.018379
# url_num_hyphens_dom                    -0.113903               -0.058324
# url_path_len                           -0.018587               -0.010334
# url_domain_len                         -0.071385               -0.012159
# url_hostname_len                       -0.069513               -0.011788
# url_num_dots                           -0.085725               -0.029524
# url_num_underscores                    -0.043561               -0.002268
# url_query_len                          -0.034905               -0.016231
# url_num_query_para                     -0.049467               -0.018736
# url_ip_present                         -0.067853               -0.029421
# url_entropy                            -0.074402                0.008478
# url_chinese_present                          NaN                     NaN
# url_port                               -0.009160               -0.002287
# html_num_tags('iframe')                 0.286591                0.034674
# html_num_tags('script')                 1.000000                0.016041
# html_num_tags('embed')                  0.016041                1.000000
# html_num_tags('object')                -0.004086                0.608177
# html_num_tags('div')                    0.289569                0.059569
# html_num_tags('head')                   0.031615               -0.002287
# html_num_tags('body')                  -0.058769                0.016492
# html_num_tags('form')                   0.282915               -0.032948
# html_num_tags('a')                      0.157016                0.016182
# html_num_tags('applet')                      NaN                     NaN
#
#                          html_num_tags('object')  html_num_tags('div')  \
# id                                     -0.016843              0.038500
# url_len                                -0.034092             -0.036667
# url_num_hyphens_dom                    -0.062946             -0.000400
# url_path_len                           -0.022368             -0.024239
# url_domain_len                         -0.034602             -0.001186
# url_hostname_len                       -0.036494             -0.000005
# url_num_dots                           -0.019709             -0.089583
# url_num_underscores                    -0.015334             -0.058513
# url_query_len                          -0.017518             -0.025677
# url_num_query_para                     -0.020220             -0.026887
# url_ip_present                          0.057298             -0.074472
# url_entropy                            -0.071461             -0.062188
# url_chinese_present                          NaN                   NaN
# url_port                               -0.002469             -0.007130
# html_num_tags('iframe')                 0.010788              0.135321
# html_num_tags('script')                -0.004086              0.289569
# html_num_tags('embed')                  0.608177              0.059569
# html_num_tags('object')                 1.000000              0.065655
# html_num_tags('div')                    0.065655              1.000000
# html_num_tags('head')                  -0.002469              0.003933
# html_num_tags('body')                   0.020369             -0.016906
# html_num_tags('form')                   0.005631              0.254996
# html_num_tags('a')                      0.024709              0.415403
# html_num_tags('applet')                      NaN                   NaN
#
#                          html_num_tags('head')  html_num_tags('body')  \
# id                                   -0.020611              -0.037040
# url_len                               0.027708               0.047080
# url_num_hyphens_dom                   0.029801               0.002167
# url_path_len                          0.035421              -0.002048
# url_domain_len                       -0.007659               0.052404
# url_hostname_len                     -0.007583               0.052541
# url_num_dots                         -0.024565              -0.034114
# url_num_underscores                   0.019009               0.008656
# url_query_len                         0.003574               0.092019
# url_num_query_para                    0.000285               0.088190
# url_ip_present                       -0.005271              -0.026612
# url_entropy                           0.015863               0.045529
# url_chinese_present                        NaN                    NaN
# url_port                             -0.000410              -0.001495
# html_num_tags('iframe')               0.004442              -0.037133
# html_num_tags('script')               0.031615              -0.058769
# html_num_tags('embed')               -0.002287               0.016492
# html_num_tags('object')              -0.002469               0.020369
# html_num_tags('div')                  0.003933              -0.016906
# html_num_tags('head')                 1.000000               0.176496
# html_num_tags('body')                 0.176496               1.000000
# html_num_tags('form')                 0.043969               0.003177
# html_num_tags('a')                    0.000959              -0.008022
# html_num_tags('applet')                    NaN                    NaN
#
#                          html_num_tags('form')  html_num_tags('a')  \
# id                                    0.017098            0.010064
# url_len                               0.014908           -0.022839
# url_num_hyphens_dom                   0.057764           -0.038158
# url_path_len                         -0.001924           -0.010630
# url_domain_len                        0.020192           -0.031333
# url_hostname_len                      0.022462           -0.030827
# url_num_dots                         -0.088786           -0.042389
# url_num_underscores                  -0.067010           -0.014733
# url_query_len                         0.028988           -0.016751
# url_num_query_para                    0.028738           -0.020022
# url_ip_present                       -0.095059           -0.039869
# url_entropy                           0.002133           -0.041228
# url_chinese_present                        NaN                 NaN
# url_port                             -0.000133                 NaN
# html_num_tags('iframe')               0.157678            0.042827
# html_num_tags('script')               0.282915            0.157016
# html_num_tags('embed')               -0.032948            0.016182
# html_num_tags('object')               0.005631            0.024709
# html_num_tags('div')                  0.254996            0.415403
# html_num_tags('head')                 0.043969            0.000959
# html_num_tags('body')                 0.003177           -0.008022
# html_num_tags('form')                 1.000000            0.111707
# html_num_tags('a')                    0.111707            1.000000
# html_num_tags('applet')                    NaN                 NaN
#
#                          html_num_tags('applet')
# id                                           NaN
# url_len                                      NaN
# url_num_hyphens_dom                          NaN
# url_path_len                                 NaN
# url_domain_len                               NaN
# url_hostname_len                             NaN
# url_num_dots                                 NaN
# url_num_underscores                          NaN
# url_query_len                                NaN
# url_num_query_para                           NaN
# url_ip_present                               NaN
# url_entropy                                  NaN
# url_chinese_present                          NaN
# url_port                                     NaN
# html_num_tags('iframe')                      NaN
# html_num_tags('script')                      NaN
# html_num_tags('embed')                       NaN
# html_num_tags('object')                      NaN
# html_num_tags('div')                         NaN
# html_num_tags('head')                        NaN
# html_num_tags('body')                        NaN
# html_num_tags('form')                        NaN
# html_num_tags('a')                           NaN
# html_num_tags('applet')                      NaN
#
# [24 rows x 24 columns]

# %%
test_data.isna().sum()
# Out:
# id                           0
# url_len                      0
# url_num_hyphens_dom          0
# url_path_len                 0
# url_domain_len               0
# url_hostname_len             0
# url_num_dots                 0
# url_num_underscores          0
# url_query_len                0
# url_num_query_para           0
# url_ip_present               0
# url_entropy                  0
# url_chinese_present          0
# url_port                     0
# html_num_tags('iframe')      0
# html_num_tags('script')      0
# html_num_tags('embed')       0
# html_num_tags('object')      0
# html_num_tags('div')         0
# html_num_tags('head')        0
# html_num_tags('body')        0
# html_num_tags('form')      467
# html_num_tags('a')           0
# html_num_tags('applet')      0
# dtype: int64

# %%
test_data["html_num_tags('a')"].max()
# Out:
# 11868.0

# %%
plt.hist(test_data["html_num_tags('a')"])
# Out:
# (array([1.975e+03, 2.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([    0. ,  1186.8,  2373.6,  3560.4,  4747.2,  5934. ,  7120.8,
#          8307.6,  9494.4, 10681.2, 11868. ]),
#  <BarContainer object of 10 artists>)

# %%
test_data["html_num_tags('a')"].nunique()
# Out:
# 240

# %%
plt.plot(test_data["html_num_tags('a')"])

# %%
test_data["html_num_tags('a')"].min()
# Out:
# 0.0

# %%
test_data["html_num_tags('a')"].median()
# Out:
# 15.5

# %%
#"html_num_tags('a')" -> median
test_data.loc[test_data["html_num_tags('a')"].isnull(),"html_num_tags('a')"] = test_data["html_num_tags('a')"].median()

# %%
plt.plot(test_data["html_num_tags('form')"])

# %%
plt.hist(test_data["html_num_tags('form')"])
# Out:
# (array([1.622e+03, 2.900e+02, 4.300e+01, 1.500e+01, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 3.000e+00]),
#  array([ 0. ,  1.9,  3.8,  5.7,  7.6,  9.5, 11.4, 13.3, 15.2, 17.1, 19. ]),
#  <BarContainer object of 10 artists>)

# %%
#"html_num_tags('form')" -> median
test_data.loc[test_data["html_num_tags('form')"].isnull(),"html_num_tags('form')"] = test_data["html_num_tags('form')"].median()

# %%
test_data.isna().sum()
# Out:
# id                         0
# url_len                    0
# url_num_hyphens_dom        0
# url_path_len               0
# url_domain_len             0
# url_hostname_len           0
# url_num_dots               0
# url_num_underscores        0
# url_query_len              0
# url_num_query_para         0
# url_ip_present             0
# url_entropy                0
# url_chinese_present        0
# url_port                   0
# html_num_tags('iframe')    0
# html_num_tags('script')    0
# html_num_tags('embed')     0
# html_num_tags('object')    0
# html_num_tags('div')       0
# html_num_tags('head')      0
# html_num_tags('body')      0
# html_num_tags('form')      0
# html_num_tags('a')         0
# html_num_tags('applet')    0
# dtype: int64

# %%
def test_data_prepro():
    '''
    
    '''
    test_data = pd.read_csv('test.csv')
    # url_path_len: Na -> median
    test_data.loc[test_data['url_path_len'].isnull(),'url_path_len'] = test_data['url_path_len'].median()
    #fill na
    test_data['url_hostname_len'] = test_data['url_hostname_len'].fillna(test_data['url_domain_len'])
    test_data.loc[test_data['url_hostname_len'].isnull(),'url_hostname_len'] = test_data['url_hostname_len'].median()
    
    test_data['url_domain_len'] = test_data['url_domain_len'].fillna(test_data['url_hostname_len'])
    # url_domain_len: Na -> median
    test_data.loc[test_data['url_domain_len'].isnull(),'url_domain_len'] = test_data['url_domain_len'].median()
