# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
#read Kor
from matplotlib import font_manager, rc
# font_path = "C:/Windows/Fonts/NGULIM.TTF"
# font = font_manager.FontProperties(fname=font_path).get_name()
# rc('font', family=font)
# %matplotlib inline
rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format = 'retina'

# %%
filename='train.csv'
data= pd.read_csv(filename)

# %% [markdown]
# ### Classification

# %%
var='label'
sns.countplot(x=data[var])
plt.show()
# Out:
# findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### Correlation

# %%
data.corr()
# Out:
#                           url_len  url_num_hyphens_dom  url_path_len  \
# url_len                  1.000000            -0.022953      0.943058
# url_num_hyphens_dom     -0.022953             1.000000     -0.097901
# url_path_len             0.943058            -0.097901      1.000000
# url_domain_len           0.003787             0.594874     -0.124312
# url_hostname_len         0.004117             0.596240     -0.124199
# url_num_dots             0.265846            -0.086996      0.200483
# url_num_underscores      0.313610            -0.060620      0.263025
# url_query_len            0.325916             0.002167      0.015388
# url_num_query_para       0.275240            -0.002100      0.014283
# url_ip_present          -0.064589            -0.124119     -0.033650
# url_entropy              0.271695             0.074786      0.148673
# url_chinese_present           NaN                  NaN           NaN
# url_port                 0.045975            -0.022807      0.051577
# html_num_tags('iframe')  0.019931             0.006434      0.031427
# html_num_tags('script') -0.031145            -0.100745      0.002900
# html_num_tags('embed')  -0.010579            -0.051755     -0.002139
# html_num_tags('object') -0.021014            -0.048505     -0.014861
# html_num_tags('div')    -0.015684            -0.010727     -0.010336
# html_num_tags('head')    0.070786             0.050888      0.072812
# html_num_tags('body')    0.045527            -0.037459     -0.004275
# html_num_tags('form')   -0.036414             0.047858     -0.041040
# html_num_tags('a')      -0.022283            -0.037136     -0.010525
# html_num_tags('applet')       NaN                  NaN           NaN
#
#                          url_domain_len  url_hostname_len  url_num_dots  \
# url_len                        0.003787          0.004117      0.265846
# url_num_hyphens_dom            0.594874          0.596240     -0.086996
# url_path_len                  -0.124312         -0.124199      0.200483
# url_domain_len                 1.000000          0.998949      0.073088
# url_hostname_len               0.998949          1.000000      0.069218
# url_num_dots                   0.073088          0.069218      1.000000
# url_num_underscores           -0.089833         -0.091201      0.252325
# url_query_len                  0.016346          0.017311      0.213499
# url_num_query_para             0.016525          0.017465      0.182670
# url_ip_present                -0.150334         -0.168709      0.186597
# url_entropy                    0.161295          0.164477      0.186755
# url_chinese_present                 NaN               NaN           NaN
# url_port                      -0.003697         -0.027117      0.033792
# html_num_tags('iframe')       -0.007128         -0.006514     -0.001028
# html_num_tags('script')       -0.104146         -0.101376     -0.084727
# html_num_tags('embed')        -0.011061         -0.010341     -0.030866
# html_num_tags('object')       -0.028923         -0.030305     -0.017066
# html_num_tags('div')          -0.002282         -0.001095     -0.031888
# html_num_tags('head')          0.011320          0.011210     -0.026245
# html_num_tags('body')          0.030886          0.031187     -0.000420
# html_num_tags('form')          0.029068          0.032199     -0.070070
# html_num_tags('a')            -0.037149         -0.035864     -0.030922
# html_num_tags('applet')             NaN               NaN           NaN
#
#                          url_num_underscores  url_query_len  \
# url_len                             0.313610       0.325916
# url_num_hyphens_dom                -0.060620       0.002167
# url_path_len                        0.263025       0.015388
# url_domain_len                     -0.089833       0.016346
# url_hostname_len                   -0.091201       0.017311
# url_num_dots                        0.252325       0.213499
# url_num_underscores                 1.000000       0.238275
# url_query_len                       0.238275       1.000000
# url_num_query_para                  0.237910       0.838152
# url_ip_present                     -0.048530      -0.047342
# url_entropy                         0.249614       0.356455
# url_chinese_present                      NaN            NaN
# url_port                            0.082260      -0.008699
# html_num_tags('iframe')            -0.023664      -0.029652
# html_num_tags('script')            -0.058133      -0.069966
# html_num_tags('embed')             -0.028490      -0.023136
# html_num_tags('object')            -0.021347      -0.010979
# html_num_tags('div')               -0.018447      -0.017879
# html_num_tags('head')               0.060128       0.000145
# html_num_tags('body')               0.029485       0.149054
# html_num_tags('form')              -0.074647      -0.002468
# html_num_tags('a')                 -0.004400      -0.025314
# html_num_tags('applet')                  NaN            NaN
#
#                          url_num_query_para  url_ip_present  ...  \
# url_len                            0.275240       -0.064589  ...
# url_num_hyphens_dom               -0.002100       -0.124119  ...
# url_path_len                       0.014283       -0.033650  ...
# url_domain_len                     0.016525       -0.150334  ...
# url_hostname_len                   0.017465       -0.168709  ...
# url_num_dots                       0.182670        0.186597  ...
# url_num_underscores                0.237910       -0.048530  ...
# url_query_len                      0.838152       -0.047342  ...
# url_num_query_para                 1.000000       -0.046220  ...
# url_ip_present                    -0.046220        1.000000  ...
# url_entropy                        0.326074       -0.159034  ...
# url_chinese_present                     NaN             NaN  ...
# url_port                          -0.008493        0.110379  ...
# html_num_tags('iframe')           -0.032459       -0.025720  ...
# html_num_tags('script')           -0.068069       -0.083789  ...
# html_num_tags('embed')            -0.022588       -0.031671  ...
# html_num_tags('object')           -0.016102        0.050671  ...
# html_num_tags('div')              -0.016305       -0.033419  ...
# html_num_tags('head')             -0.017280        0.011231  ...
# html_num_tags('body')              0.108940       -0.018812  ...
# html_num_tags('form')             -0.007007       -0.082826  ...
# html_num_tags('a')                -0.025140       -0.038185  ...
# html_num_tags('applet')                 NaN             NaN  ...
#
#                          html_num_tags('iframe')  html_num_tags('script')  \
# url_len                                 0.019931                -0.031145
# url_num_hyphens_dom                     0.006434                -0.100745
# url_path_len                            0.031427                 0.002900
# url_domain_len                         -0.007128                -0.104146
# url_hostname_len                       -0.006514                -0.101376
# url_num_dots                           -0.001028                -0.084727
# url_num_underscores                    -0.023664                -0.058133
# url_query_len                          -0.029652                -0.069966
# url_num_query_para                     -0.032459                -0.068069
# url_ip_present                         -0.025720                -0.083789
# url_entropy                            -0.014732                -0.094404
# url_chinese_present                          NaN                      NaN
# url_port                                0.008030                -0.014465
# html_num_tags('iframe')                 1.000000                 0.279593
# html_num_tags('script')                 0.279593                 1.000000
# html_num_tags('embed')                  0.068049                 0.023725
# html_num_tags('object')                 0.046788                -0.003838
# html_num_tags('div')                    0.051412                 0.112905
# html_num_tags('head')                  -0.024010                 0.050400
# html_num_tags('body')                  -0.006026                 0.009779
# html_num_tags('form')                   0.123502                 0.242490
# html_num_tags('a')                      0.051647                 0.096613
# html_num_tags('applet')                      NaN                      NaN
#
#                          html_num_tags('embed')  html_num_tags('object')  \
# url_len                               -0.010579                -0.021014
# url_num_hyphens_dom                   -0.051755                -0.048505
# url_path_len                          -0.002139                -0.014861
# url_domain_len                        -0.011061                -0.028923
# url_hostname_len                      -0.010341                -0.030305
# url_num_dots                          -0.030866                -0.017066
# url_num_underscores                   -0.028490                -0.021347
# url_query_len                         -0.023136                -0.010979
# url_num_query_para                    -0.022588                -0.016102
# url_ip_present                        -0.031671                 0.050671
# url_entropy                            0.018674                -0.032263
# url_chinese_present                         NaN                      NaN
# url_port                              -0.005820                -0.005694
# html_num_tags('iframe')                0.068049                 0.046788
# html_num_tags('script')                0.023725                -0.003838
# html_num_tags('embed')                 1.000000                 0.500423
# html_num_tags('object')                0.500423                 1.000000
# html_num_tags('div')                  -0.009657                 0.037768
# html_num_tags('head')                  0.001640                 0.001604
# html_num_tags('body')                 -0.009193                 0.011394
# html_num_tags('form')                 -0.026411                 0.006561
# html_num_tags('a')                     0.011889                 0.078715
# html_num_tags('applet')                     NaN                      NaN
#
#                          html_num_tags('div')  html_num_tags('head')  \
# url_len                             -0.015684               0.070786
# url_num_hyphens_dom                 -0.010727               0.050888
# url_path_len                        -0.010336               0.072812
# url_domain_len                      -0.002282               0.011320
# url_hostname_len                    -0.001095               0.011210
# url_num_dots                        -0.031888              -0.026245
# url_num_underscores                 -0.018447               0.060128
# url_query_len                       -0.017879               0.000145
# url_num_query_para                  -0.016305              -0.017280
# url_ip_present                      -0.033419               0.011231
# url_entropy                         -0.024119              -0.005383
# url_chinese_present                       NaN                    NaN
# url_port                            -0.005563               0.000617
# html_num_tags('iframe')              0.051412              -0.024010
# html_num_tags('script')              0.112905               0.050400
# html_num_tags('embed')              -0.009657               0.001640
# html_num_tags('object')              0.037768               0.001604
# html_num_tags('div')                 1.000000               0.000571
# html_num_tags('head')                0.000571               1.000000
# html_num_tags('body')               -0.007206               0.201544
# html_num_tags('form')                0.119981               0.033959
# html_num_tags('a')                   0.835108               0.009157
# html_num_tags('applet')                   NaN                    NaN
#
#                          html_num_tags('body')  html_num_tags('form')  \
# url_len                               0.045527              -0.036414
# url_num_hyphens_dom                  -0.037459               0.047858
# url_path_len                         -0.004275              -0.041040
# url_domain_len                        0.030886               0.029068
# url_hostname_len                      0.031187               0.032199
# url_num_dots                         -0.000420              -0.070070
# url_num_underscores                   0.029485              -0.074647
# url_query_len                         0.149054              -0.002468
# url_num_query_para                    0.108940              -0.007007
# url_ip_present                       -0.018812              -0.082826
# url_entropy                           0.059220              -0.026555
# url_chinese_present                        NaN                    NaN
# url_port                             -0.003457              -0.012084
# html_num_tags('iframe')              -0.006026               0.123502
# html_num_tags('script')               0.009779               0.242490
# html_num_tags('embed')               -0.009193              -0.026411
# html_num_tags('object')               0.011394               0.006561
# html_num_tags('div')                 -0.007206               0.119981
# html_num_tags('head')                 0.201544               0.033959
# html_num_tags('body')                 1.000000               0.032720
# html_num_tags('form')                 0.032720               1.000000
# html_num_tags('a')                   -0.006701               0.093717
# html_num_tags('applet')                    NaN                    NaN
#
#                          html_num_tags('a')  html_num_tags('applet')
# url_len                           -0.022283                      NaN
# url_num_hyphens_dom               -0.037136                      NaN
# url_path_len                      -0.010525                      NaN
# url_domain_len                    -0.037149                      NaN
# url_hostname_len                  -0.035864                      NaN
# url_num_dots                      -0.030922                      NaN
# url_num_underscores               -0.004400                      NaN
# url_query_len                     -0.025314                      NaN
# url_num_query_para                -0.025140                      NaN
# url_ip_present                    -0.038185                      NaN
# url_entropy                       -0.026799                      NaN
# url_chinese_present                     NaN                      NaN
# url_port                          -0.008064                      NaN
# html_num_tags('iframe')            0.051647                      NaN
# html_num_tags('script')            0.096613                      NaN
# html_num_tags('embed')             0.011889                      NaN
# html_num_tags('object')            0.078715                      NaN
# html_num_tags('div')               0.835108                      NaN
# html_num_tags('head')              0.009157                      NaN
# html_num_tags('body')             -0.006701                      NaN
# html_num_tags('form')              0.093717                      NaN
# html_num_tags('a')                 1.000000                      NaN
# html_num_tags('applet')                 NaN                      NaN
#
# [23 rows x 23 columns]

# %%
plt.figure(figsize = (15, 15))
#categorical한 것들은 안된다. 
sns.heatmap(data.corr(), 
            annot = False,            # 숫자(상관계수) 표기 여부
            fmt = '.3f',             # 숫자 포멧 : 소수점 3자리까지 표기
            cmap = 'RdYlBu_r',       # 칼라맵
            vmin = -1, vmax = 1)     # 값의 최소, 최대값값
plt.show()

# %% [markdown]
# ### 범주 -> 숫자

# %%
sns.barplot(x="label", y="url_len", data=data)
plt.grid()
plt.show()

# %%
sns.scatterplot(x='Temp', y='Ozone', data = air)
